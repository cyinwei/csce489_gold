# %% [markdown]
# # pics

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Feature Importance

# %%
import pandas as pd
from scripts import Munger as mg
from sklearn.ensemble import ExtraTreesClassifier
import numpy as np
import matplotlib.pyplot as plt

def feature_importance(train, test, features, predict, trees=10, state=None):
    
    X = train[features]
    y = train[predict]

    # Build a forest and compute the feature importances
    forest = ExtraTreesClassifier(n_estimators=trees,
                                  random_state=state)

    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]

    # Print the feature ranking
    print("Feature ranking:")

    for f in range(X.shape[1]):
        print '%d.' % (f + 1), X.columns.values[indices[f]], '(%f)' % importances[indices[f]]

    # Plot the feature importances of the forest
    plt.figure()
    plt.title("Feature importances")
    plt.bar(range(X.shape[1]), importances[indices],
           color="r", yerr=std[indices], align="center")
    plt.xticks(range(X.shape[1]), [ X.columns.values[i] for i in indices], rotation=75)
    plt.xlim([-1, X.shape[1]])
    plt.show()

    X = test[features]
    y = test[predict]

    print 'Score:', forest.score(X,y)

# %% [markdown]
# ### TFIDF Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def tfidf_vectorize(train, test, maxdf=0.8, mindf=0.05):
    tfidf = TfidfVectorizer(stop_words='english', max_df=maxdf, min_df=mindf)

    train_tfidf = tfidf.fit_transform(train)
    test_tfidf = tfidf.transform(test)
    
    return {'train_tfidf': train_tfidf,'test_tfidf': test_tfidf}

# %% [markdown]
# ### Clustering

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans

def cluster(train, test, clusters=10, iterations=300, init=10):
    km = KMeans(n_clusters=clusters, init='k-means++', max_iter=iterations, n_init=init)

    train_preds = km.fit_predict(train)
    test_preds = km.predict(test)
    
    return {'train_preds': train_preds, 'test_preds': test_preds}

# %% [markdown]
# ### Full Function

# %%
def show_feature_importance(train_filename, test_filename, features, predict):
    # Load datasets
    train = pd.read_csv(train_filename)
    test = pd.read_csv(test_filename)

    # Munge data
    train = mg.munge_dataset(train)
    test = mg.munge_dataset(test)

    if 'watson cluster' in features:
        # Create Watson Vector
        watson = ['Watson Anger', 'Watson Disgust', 'Watson Fear',
                   'Watson Joy', 'Watson Sadness', 'Watson Analytical',
                   'Watson Confident', 'Watson Tenative', 'Watson Openness',
                   'Watson Conscientiousness', 'Watson Extraversion',
                   'Watson Agreeableness', 'Watson Emotional Range'] 
        train_watson_vector = train[watson].values
        test_watson_vector = test[watson].values

        # Cluster by Watson Vector
        preds = cluster(train_watson_vector, test_watson_vector, 200, 300, 10)
        train['watson cluster'] = preds['train_preds']
        test['watson cluster'] = preds['test_preds']

    if 'body cluster' in features:
        # Create TFIDF vector for body
        tfidf = tfidf_vectorize(train['body'], test['body'], maxdf=0.8, mindf=0.05)
        train_tfidf = tfidf['train_tfidf']
        test_tfidf = tfidf['train_tfidf']

        # Cluster by Body TFIDF Vector
        preds = cluster(train_tfidf, test_tfidf, 200, 300, 10)
        train['body cluster'] = preds['train_preds']
        test['body cluster'] = preds['test_preds']

    # Map gilded to boolean
    train['gilded'] = train['gilded'].astype(bool)
    test['gilded'] = test['gilded'].astype(bool)

    # Print feature importance
    feature_importance(train, test, features, predict, trees=50, state=None)

# %% [markdown]
# ## Gilded Feature Analysis

# %%
features = [
    'Score Bracket', 
    'Contains MD', 
    'Word Count', 
    'Time of Day', 
    'watson cluster',
    'body cluster',
    'Grammer Errors',
    'Sentiment Label',
    'Contains Flair',
    'Watson Anger', 
    'Watson Disgust', 
    'Watson Fear',
    'Watson Joy', 
    'Watson Sadness', 
    'Watson Analytical',
    'Watson Confident', 
    'Watson Tenative', 
    'Watson Openness',
    'Watson Conscientiousness', 
    'Watson Extraversion',
    'Watson Agreeableness', 
    'Watson Emotional Range'
]

show_feature_importance('./mytrain/addedpics_train.csv', 
                        './mytest/addedpics_test.csv', 
                        features, 
                        'gilded')
# Out:
# Feature ranking:
# 1. Score Bracket (0.183877)
# 2. Word Count (0.075479)
# 3. Contains MD (0.073789)
# 4. body cluster (0.062410)
# 5. Grammer Errors (0.047299)
# 6. Watson Conscientiousness (0.045156)
# 7. Watson Extraversion (0.041659)
# 8. Watson Joy (0.041608)
# 9. Watson Agreeableness (0.038956)
# 10. Watson Emotional Range (0.038829)
# 11. Watson Sadness (0.037176)
# 12. Watson Anger (0.036912)
# 13. Watson Disgust (0.036498)
# 14. Watson Fear (0.035045)
# 15. Watson Openness (0.034790)
# 16. watson cluster (0.034515)
# 17. Time of Day (0.032736)
# 18. Watson Tenative (0.032578)
# 19. Watson Analytical (0.029307)
# 20. Sentiment Label (0.026729)
# 21. Watson Confident (0.014653)
# 22. Contains Flair (0.000000)
# Score: 0.825

# %% [markdown]
# ## Score Bracket Feature Analyis

# %%
features = [
    'Contains MD', 
    'Word Count', 
    'Time of Day', 
    'watson cluster',
    'body cluster',
    'Grammer Errors',
    'Sentiment Label',
    'Contains Flair',
    'Watson Anger', 
    'Watson Disgust', 
    'Watson Fear',
    'Watson Joy', 
    'Watson Sadness', 
    'Watson Analytical',
    'Watson Confident', 
    'Watson Tenative', 
    'Watson Openness',
    'Watson Conscientiousness', 
    'Watson Extraversion',
    'Watson Agreeableness', 
    'Watson Emotional Range'
]

show_feature_importance('./mytrain/addedpics_train.csv', 
                        './mytest/addedpics_test.csv', 
                        features, 
                        'Score Bracket')
# Out:
# Feature ranking:
# 1. Watson Disgust (0.065730)
# 2. Watson Agreeableness (0.060357)
# 3. Watson Extraversion (0.059810)
# 4. Watson Openness (0.059440)
# 5. Watson Sadness (0.059231)
# 6. Watson Conscientiousness (0.057267)
# 7. Watson Anger (0.055382)
# 8. Word Count (0.054669)
# 9. Watson Fear (0.054123)
# 10. Watson Joy (0.053256)
# 11. watson cluster (0.053022)
# 12. Grammer Errors (0.049964)
# 13. Watson Emotional Range (0.049149)
# 14. body cluster (0.047741)
# 15. Time of Day (0.046469)
# 16. Contains MD (0.042156)
# 17. Watson Analytical (0.038745)
# 18. Watson Tenative (0.038433)
# 19. Sentiment Label (0.035882)
# 20. Watson Confident (0.019176)
# 21. Contains Flair (0.000000)
# Score: 0.6775
